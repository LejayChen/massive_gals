# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-100, 100, 10000)

# %%
def f(x, alpha):
    return 1/np.sqrt(2*np.pi)*np.exp(-x**2/2)*(1+alpha*(x**3-3*x))

def f2(x, alpha):
    return 1/np.sqrt(2*np.pi)*np.exp(-x**2/2)*alpha*(x**4-3*x**2)

def dfdx(x, alpha, step):
    return (f(x, alpha)-f(x-step, alpha))/(step)

def func(x, alpha):
    return -x - alpha*x**4 + 6*alpha*x**2 - 3*alpha

# %%
plt.figure(figsize = (15, 6))
plt.xlim([-5,5])
plt.plot(x,f(x, 0.05))
plt.plot(x,f(x, 0.0),'--')
plt.grid()

# %%
a = 0.05

# plt.figure(figsize = (15, 6))
# plt.plot(x,dfdx(x, a, 0.0001))

# plt.xlim([-5,5])
# plt.grid()


print(dfdx(-0.133, a, 0.0001))
# Out:
# -0.004608690103991009

# %%
x = np.linspace(-100, -0.133/3, 10000)
summ = 0
alpha = 0.05
for i in range(len(x)-1):
    summ +=(x[i+1]-x[i])*f(x[i], alpha)

print(summ)
# Out:
# 0.5002020503596062
