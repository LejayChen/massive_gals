# %%
# %matplotlib inline
# Out:
# /Users/lejay/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:232: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %% [markdown]
# # XKCD
#
#
# Shows how to create an xkcd-like plot.

# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
matplotlib.font_manager.findfont('Humor Sans')
# Out:
# '/Users/lejay/anaconda3/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/Humor-Sans-1.0.ttf'

# %%
plt.get_backend()
# Out:
# 'module://ipykernel.pylab.backend_inline'

# %%
with plt.xkcd():
    # Based on "Stove Ownership" from XKCD by Randall Munroe
    # http://xkcd.com/418/

    fig = plt.figure()
    ax = fig.add_axes((0.1, 0.2, 0.8, 0.7))
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    plt.xticks([])
    plt.yticks([])
    ax.set_ylim([-30, 10])

    data = np.ones(100)
    data[70:] -= np.arange(30)

    plt.annotate(
        'THE DAY I REALIZED\nI COULD COOK BACON\nWHENEVER I WANTED',
        xy=(70, 1), arrowprops=dict(arrowstyle='->'), xytext=(15, -10))

    plt.plot(data)

    plt.xlabel('time')
    plt.ylabel('my overall health')
    fig.text(
        0.5, 0.05,
        '"Stove Ownership" from xkcd by Randall Munroe',
        ha='center')

# %%
with plt.xkcd():
    # Based on "The Data So Far" from XKCD by Randall Munroe
    # http://xkcd.com/373/

    fig = plt.figure()
    ax = fig.add_axes((0.1, 0.2, 0.8, 0.7))
    ax.bar([0, 1], [0, 100], 0.25)
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    ax.xaxis.set_ticks_position('bottom')
    ax.set_xticks([0, 1])
    ax.set_xlim([-0.5, 1.5])
    ax.set_ylim([0, 110])
    ax.set_xticklabels(['CONFIRMED BY\nEXPERIMENT', 'REFUTED BY\nEXPERIMENT'])
    plt.yticks([])

    plt.title("CLAIMS OF SUPERNATURAL POWERS")

    fig.text(
        0.5, 0.02,
        '"The Data So Far" from xkcd by Randall Munroe',
        ha='center')

plt.show()

# %%
bin_number=14
bin_edges = 10 ** np.linspace(1.0, 2.845, num=bin_number + 1)
areas = np.array([])
for i in range(len(bin_edges[:-1])):
    areas = np.append(areas, (bin_edges[i + 1] ** 2 - bin_edges[i] ** 2) * np.pi)

# %%
count_radial_il = np.load('radial_tot_il_0.4.npy')  

with plt.xkcd():
    plt.figure(figsize=(7,6))
    plt.errorbar(bin_edges[:-1], count_radial_il*3.3,np.sqrt(count_radial_il*3.3*areas*200)/areas/200,fmt='--or',linewidth=2,label=r'Illustris-1 $z=0.4$')

    # shade region
    plt.axvspan(9, 25, alpha=0.1, color='k')

    plt.xscale('log')
    plt.yscale('log')
    plt.xlim([10,700])
    plt.xlabel('Projected Radius [kpc]', fontsize=20)
    plt.ylabel('N kpc$^{-2}$ Central$^{-1}$ dr', fontsize=20)
    plt.title('Number Density Profiles ($\log(M_{cen}/M_\odot)>11.15$)', fontsize=16)
    plt.legend(fontsize=18)
    plt.tight_layout()
    plt.grid(color='k', linestyle='-', linewidth=1, alpha=0.2)
plt.savefig('figures/TNG_Obs_compare_xkcd.png')
# Out:
# /Users/lejay/anaconda3/lib/python3.6/site-packages/matplotlib/mathtext.py:843: MathTextWarning: Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.
#   MathTextWarning)
