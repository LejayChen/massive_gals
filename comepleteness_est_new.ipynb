# %%
import numpy as np
from astropy.table import Table
from astropy.io import ascii, fits
import matplotlib.pyplot as plt

# %%
path = 'completeness_curve_v2/curves/'
comp_all_50 = np.genfromtxt(path+'comp_bootstrap_all_all_8.5_9.5_0.5_0.7.txt')
comp_all = np.median(comp_all_50, axis=0)
comp_all_l = np.percentile(comp_all_50,16, axis=0)
comp_all_h = np.percentile(comp_all_50,84, axis=0)

# %%
bin_number=14
bin_edges = 10 ** np.linspace(1.0, 2.845, num=bin_number + 1)

# %%
plt.figure(figsize = (8, 5))
plt.plot(bin_edges[:-1],comp_all_h)
plt.show()
